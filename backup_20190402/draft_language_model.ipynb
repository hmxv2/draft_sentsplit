# %%
import json
import pickle
import random

import torch
from torch import nn, optim
from torch import autograd
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
import torch.nn.utils.rnn as rnn_utils

import nltk
from nltk.translate.bleu_score import SmoothingFunction
from nltk.translate.bleu_score import sentence_bleu
import time

import copy

from Vocab import Vocab

import torch
torch.cuda.set_device(0)

print('import over')
# Out:
# import over

# %%
def batch_words2sentence(words_list):
    return [' '.join(words) for words in words_list]
def batch_tokens2words(tokens_list, vocab):
    ##    para: tokens_list is list[list] type
    ##    return: words_list corresponding to tokens
    return [[vocab.token2word[token] for token in tokens] for tokens in tokens_list]

def batch_tokens_remove_eos(tokens_list, vocab):
    ##    para: tokens_list is list[list] type
    ##    return pure tokens_list removed eos symbol
    result=[]
    for tokens in tokens_list:
        tokens_filtered=[]
        for token in tokens:
            if token == vocab.word2token['<eos>']:
#                 tokens_filtered.append(token)
                break
            else:
                tokens_filtered.append(token)
        result.append(tokens_filtered)
    return result

def batch_tokens_bleu(references, candidates, smooth_epsilon=0.001):
    ##    para: references and candidates are list[list] type
    ##    return: list of BLEU for every sample
    ##
    bleu_scores=[]
    for ref, candidate in zip(references, candidates):
        if min(len(ref), len(candidate))<4:
            bleu_scores.append(0)
        else:
            bleu_scores.append(sentence_bleu([ref], candidate, smoothing_function = SmoothingFunction(epsilon=smooth_epsilon).method1))
    return bleu_scores

with open('data_set/vocab.pk', 'rb') as f:
    vocab=pickle.load(f)
    
batch_tokens_bleu([[1,2,3,4,5,6]], [[2,3,1,4,5]])
# Out:
# [0.021744100219015735]

# %%
def get_labels(sents, lens, vocab):
    labels = copy.deepcopy(sents)
    for idx, sent in enumerate(labels):
        sent.insert(lens[idx], vocab.word2token['<eos>'])
        
    return labels

def get_inputs(sents, lens, vocab):
    inputs = copy.deepcopy(sents)
    lens_=copy.deepcopy(lens)
    
    for sent in inputs:
        sent.insert(0, vocab.word2token['<sos>'])
    for idx in range(len(lens_)):
        lens_[idx]+=1
    
    return inputs, lens_

with open('./data_set/split_data_set/train_complex_sents.pk', 'rb') as f:
    split_train_set_inputs = pickle.load(f)
with open('./data_set/split_data_set/train_complex_sent_lens.pk', 'rb') as f:
    split_train_set_input_lens = pickle.load(f)
# with open('./data_set/split_data_set/train_pseudo_labels.pk', 'rb') as f:
#     split_pseudo_train_set_labels = pickle.load(f)
    
with open('./data_set/split_data_set/validation_complex_sents.pk', 'rb') as f:
    split_valid_set_inputs = pickle.load(f)
with open('./data_set/split_data_set/validation_complex_sent_lens.pk', 'rb') as f:
    split_valid_set_input_lens = pickle.load(f)
# with open('./data_set/split_data_set/validation_labels.pk', 'rb') as f:
#     split_pseudo_valid_set_labels = pickle.load(f)

# %%
split_train_set_labels = get_labels(split_train_set_inputs, split_train_set_input_lens, vocab)
split_train_set_inputs, split_train_set_input_lens = get_inputs(split_train_set_inputs, split_train_set_input_lens, vocab)
print(len(split_train_set_inputs), len(split_train_set_input_lens))

split_valid_set_labels = get_labels(split_valid_set_inputs, split_valid_set_input_lens, vocab)
split_valid_set_inputs, split_valid_set_input_lens = get_inputs(split_valid_set_inputs, split_valid_set_input_lens, vocab)
print(len(split_valid_set_inputs), len(split_valid_set_labels))
# Out:
# 989944 989944
# 5000 5000

# %%
class LanguageModel(nn.Module):
    def __init__(self, use_cuda, hidden_dim, input_dim, vocab):#, pre_train_weight, is_fix_word_vector = 1):
        super(LanguageModel, self).__init__()
        
        self.use_cuda = use_cuda
        self.input_dim=input_dim
        self.hidden_dim=hidden_dim
        self.vocab = vocab
        
        self.lstm=torch.nn.LSTM(input_size=self.input_dim, 
                                hidden_size= self.hidden_dim, 
                                bidirectional=False,
                                batch_first=True
                               )
        
        #embedding
        self.embed=nn.Embedding(len(self.vocab.word2token), input_dim)
        #loading pre trained word embedding
        with open('data_set/pre_trained_token_embedding_300d.pk', 'rb') as f:
            pre_train_word_embedding = pickle.load(f)
            
        self.embed.weight.data.copy_(torch.FloatTensor(pre_train_word_embedding))
#         self.embed.weight.requires_grad = False


        self.weight = [1]*len(self.vocab.word2token)
        self.weight[self.vocab.word2token['<padding>']]=0
        self.cost_func = nn.CrossEntropyLoss(weight=torch.Tensor(self.weight), reduce=True)
        self.fcnn=nn.Linear(in_features = self.hidden_dim, out_features = len(self.vocab.word2token))
        
    def order(self, inputs, inputs_len):    #inputs: tensor, inputs_len: 1D tensor
        inputs_len, sort_ids = torch.sort(inputs_len, dim=0, descending=True)
        
        if self.use_cuda:
            inputs = inputs.index_select(0, Variable(sort_ids).cuda())
        else:
            inputs = inputs.index_select(0, Variable(sort_ids))
        
        _, true_order_ids = torch.sort(sort_ids, dim=0, descending=False)
        
        return inputs, inputs_len, true_order_ids
    #
    def forward(self, inputs, inputs_len):
        inputs = Variable(inputs)
        if self.use_cuda:
            inputs=inputs.cuda()
            
        inputs, sort_len, true_order_ids = self.order(inputs, inputs_len)

        in_vecs=self.embed(inputs)

        packed = rnn_utils.pack_padded_sequence(input=in_vecs, lengths=list(sort_len), batch_first =True)
        
        outputs, (hn,cn) = self.lstm(packed)
        outputs, sent_lens = rnn_utils.pad_packed_sequence(outputs)
        
        #print('outpurs size, hn size and cn size: ', outputs.size(), hn.size(), cn.size())
        outputs = outputs.transpose(0,1)  #transpose is necessary
        #print('outpurs size, hn size and cn size: ', outputs.size(), hn.size(), cn.size())
        
        #warnning: outputs, hn and cn have been sorted by sentences length so the order is wrong, now to sort them
        if self.use_cuda:
            outputs = outputs.index_select(0, Variable(true_order_ids).cuda())
        else:
            outputs = outputs.index_select(0, Variable(true_order_ids))
        
#         hn = torch.cat((hn[0], hn[1]), dim=1)
#         cn = torch.cat((cn[0], cn[1]), dim=1)
#         #print('hn size and cn size: ', hn.size(), cn.size())
        
#         if self.use_cuda:
#             hn = hn.index_select(0, Variable(true_order_ids).cuda())
#             cn = cn.index_select(0, Variable(true_order_ids).cuda())
#         else:
#             hn = hn.index_select(0, Variable(true_order_ids))
#             cn = cn.index_select(0, Variable(true_order_ids))
        logits = self.fcnn(outputs)
        return logits
    
    def get_loss(self, logits, labels):
        labels = self._tocuda(Variable(labels))
        sents = logits.size(dim=1)
        labels = labels[:, :sents]
        labels = labels.contiguous().view(-1)
        logits = logits.view(-1, len(self.vocab.word2token))
#         print('logits size: ', logits.size())
        
        return self.cost_func(logits, labels)
    
    def get_sentences_ppl(self, inputs):
        pass
        
    def _tocuda(self, var):
        if self.use_cuda:
            return var.cuda()
        else:
            return var

# %%
# def get_labels(sents, lens, vocab):
#     labels = copy.deepcopy(sents)
#     for idx, sent in enumerate(labels):
#         sent.insert(lens[idx], vocab.word2token['<eos>'])
        
#     return labels

# def get_inputs(sents, lens, vocab):
#     inputs = copy.deepcopy(sents)
#     lens_=copy.deepcopy(lens)
    
#     for sent in inputs:
#         sent.insert(0, vocab.word2token['<sos>'])
#     for idx in range(len(lens_)):
#         lens_[idx]+=1
    
#     return inputs, lens_

# id1=random.randint(0, len(split_train_set_inputs)-1)
# id2=random.randint(0, len(split_train_set_inputs)-1)
# sents=[split_train_set_inputs[id1], split_train_set_inputs[id2]]
# lens=[split_train_set_input_lens[id1], split_train_set_input_lens[id2]]
# print(sents, lens)
# labels = get_labels(sents, lens, vocab)
# inputs, lens = get_inputs(sents, lens, vocab)
# print(inputs, lens)
# print(labels)

# %%
# use_cuda = 1
# hidden_dim = 256
# input_dim = 100
# sample_num = 11

# language_model = LanguageModel(use_cuda = use_cuda, input_dim = input_dim, hidden_dim = hidden_dim, vocab = vocab)
# lm_optimizer = optim.Adam(filter(lambda p: p.requires_grad, language_model.parameters()), lr=0.005)

# if use_cuda:
#     language_model = language_model.cuda()
    
# a = time.time()

# lm_optimizer.zero_grad()#clear
# outputs = language_model.forward(torch.LongTensor(split_train_set_inputs[0:sample_num]), 
#                                              torch.LongTensor(split_train_set_input_lens[0:sample_num])
#                                               )
# loss = language_model.get_loss(outputs, torch.LongTensor(split_train_set_labels[:sample_num]))
# loss.backward()#retain_graph=True)
# lm_optimizer.step()

# print('language_model: loss is %4.7f'%loss.data[0])

# print(time.time()-a)

# %%
use_cuda = 1
hidden_dim = 2048
input_dim = 300
lr=0.005
batch_size=100
split_train_set_size=int(len(split_train_set_inputs)/1)
epochs=10000
train_bleu_mean=-1
train_bleu_max=-1

language_model = LanguageModel(use_cuda = use_cuda, input_dim = input_dim, hidden_dim = hidden_dim, vocab = vocab)
if use_cuda:
    language_model = language_model.cuda()
#pre train para
# pre_train = torch.load('./models_saved/time-[2019-01-24-17-17-59]-info=[split_model]-loss=1.704468250-bleu=0.0485-hidden_dim=256-input_dim=100-epoch=9-batch_size=200-batch_id=[1-[of]-4949]-lr=0.0050', map_location='cpu')
# split_model.load_state_dict(pre_train)
# pre_train = torch.load('./models_saved/time-[2019-01-24-17-17-59]-info=[fusion_model]-loss=2.401571035-bleu=0.0334-hidden_dim=256-input_dim=100-epoch=9-batch_size=200-batch_id=[1-[of]-4949]-lr=0.0050', map_location='cpu')
# fusion_model.load_state_dict(pre_train)

lm_optimizer = optim.Adam(filter(lambda p: p.requires_grad, language_model.parameters()), lr=0.005)


def model_train(epoch, batch_size, train_set_size):
    batch_id = 0
    valid_bleu = 0
    for start_idx in range(0, train_set_size-batch_size+1, batch_size):
#         print('batch id: ', batch_id)
            
        batch_id+=1
        end_idx = start_idx + batch_size
        
        #split model
        lm_optimizer.zero_grad()#clear
        outputs = language_model.forward(torch.LongTensor(split_train_set_inputs[start_idx:end_idx]), 
                                     torch.LongTensor(split_train_set_input_lens[start_idx:end_idx]),
                                                )
        loss = language_model.get_loss(outputs, torch.LongTensor(split_train_set_labels[start_idx:end_idx]))
        
        #optimize
        loss.backward()#retain_graph=True)
        lm_optimizer.step()
        
        
        if batch_id%50==1:
            language_model.eval()
            
            sample_num = 5
            rand_idx = random.randint(0, train_set_size-sample_num-1)
            outputs = language_model.forward(torch.LongTensor(split_train_set_inputs[rand_idx:rand_idx+batch_size]), 
                                     torch.LongTensor(split_train_set_input_lens[rand_idx:rand_idx+batch_size]),
                                                )
            loss = language_model.get_loss(outputs, torch.LongTensor(split_train_set_labels[rand_idx:rand_idx+batch_size]))
                
            info_stamp = 'split_loss={:2.9f}-train_bleu_mean={:2.9f}-train_bleu_max={:2.9f}-batch_size={:n}-epoch={:n}-batch_id=({:n}/{:n})'.format(
                              loss.data[0], train_bleu_mean, train_bleu_max, batch_size, epoch, batch_id, int(train_set_size/batch_size))
            print(info_stamp)
            
            if batch_id%50000==1:
                valid_bleu=-1
                info_stamp = 'info=[{:s}]-loss={:2.9f}-bleu={:1.4f}-hidden_dim={:n}-input_dim={:n}-epoch={:n}-batch_size={:n}-batch_id=[{:n}-[of]-{:n}]-lr={:1.4f}'.format(
                              'language_model', loss.data[0], valid_bleu, hidden_dim, input_dim, epoch, batch_size, batch_id, int(train_set_size/batch_size), lr)
                now = int(round(time.time()*1000))
                time_stamp = time.strftime('time-[%Y-%m-%d-%H-%M-%S]-',time.localtime(now/1000))
                torch.save(language_model.state_dict(), ''.join(['./models_language_model/', time_stamp, info_stamp]))

# #             #valid_set testing
#             if batch_id%1000==1:
#                 rand_idx=random.randint(0, len(split_valid_set_inputs)-batch_size-1-1)
#                 predicts = split_model.forward(torch.LongTensor(split_valid_set_inputs[rand_idx:rand_idx+batch_size]), 
#                                                  torch.LongTensor(split_valid_set_input_lens[rand_idx:rand_idx+batch_size]), 
#                                                  labels=[],#torch.LongTensor(valid_set_labels[rand_idx:rand_idx+batch_size]), 
#                                                  is_train=0, teaching_rate=1)
#                 predicts = batch_tokens_remove_eos(predicts, vocab)
#                 labels = batch_tokens_remove_eos(split_pseudo_valid_set_labels[rand_idx:rand_idx+batch_size], vocab)
                
#                 bleu_scores = batch_tokens_bleu(references=labels, candidates=predicts, smooth_epsilon=0.001)

#                 valid_bleu = 0
#                 for x in bleu_scores:
#                     valid_bleu+=x
#                 valid_bleu/=len(bleu_scores)
                       
#                 info_stamp = 'info=[{:s}]-loss={:2.9f}-bleu={:1.4f}-hidden_dim={:n}-input_dim={:n}-epoch={:n}-batch_size={:n}-batch_id=[{:n}-[of]-{:n}]-lr={:1.4f}'.format(
#                               'split_model', split_loss.data[0], valid_bleu, hidden_dim, input_dim, epoch, batch_size, batch_id, int(train_set_size/batch_size), lr)
#                 print(info_stamp, valid_bleu)
#                 now = int(round(time.time()*1000))
#                 time_stamp = time.strftime('time-[%Y-%m-%d-%H-%M-%S]-',time.localtime(now/1000))
#                 torch.save(split_model.state_dict(), ''.join(['./models_saved/', time_stamp, info_stamp]))


#                 rand_idx=random.randint(0, len(fusion_pseudo_valid_set_inputs)-batch_size-1-1)
#                 predicts = fusion_model.forward(torch.LongTensor(fusion_pseudo_valid_set_inputs[rand_idx:rand_idx+batch_size]), 
#                                                  torch.LongTensor(fusion_pseudo_valid_set_input_lens[rand_idx:rand_idx+batch_size]), 
#                                                  labels=[],#torch.LongTensor(valid_set_labels[rand_idx:rand_idx+batch_size]), 
#                                                  is_train=0, teaching_rate=1)
#                 predicts = batch_tokens_remove_eos(predicts, vocab)
#                 labels = batch_tokens_remove_eos(fusion_pseudo_valid_set_labels[rand_idx:rand_idx+batch_size], vocab)
                
#                 bleu_scores = batch_tokens_bleu(references=labels, candidates=predicts, smooth_epsilon=0.001)

#                 valid_bleu = 0
#                 for x in bleu_scores:
#                     valid_bleu+=x
#                 valid_bleu/=len(bleu_scores)
#                 info_stamp = 'info=[{:s}]-loss={:2.9f}-bleu={:1.4f}-hidden_dim={:n}-input_dim={:n}-epoch={:n}-batch_size={:n}-batch_id=[{:n}-[of]-{:n}]-lr={:1.4f}'.format(
#                               'fusion_model', fusion_loss.data[0], valid_bleu, hidden_dim, input_dim, epoch, batch_size, batch_id, int(train_set_size/batch_size), lr)
#                 print(info_stamp, valid_bleu)
#                 now = int(round(time.time()*1000))
#                 time_stamp = time.strftime('time-[%Y-%m-%d-%H-%M-%S]-',time.localtime(now/1000))
#                 torch.save(fusion_model.state_dict(), ''.join(['./models_saved/', time_stamp, info_stamp]))
                
            language_model.train()

            
for epoch in range(epochs):
    model_train(epoch, batch_size, split_train_set_size)
    
print('running time: %.2f mins'%((time.time()-start_time)/60))
# Out:
# split_loss=8.822279930-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1/9899)
# split_loss=11.204010963-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(51/9899)
# split_loss=7.924545288-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(101/9899)
# split_loss=8.429313660-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(151/9899)
# split_loss=8.397708893-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(201/9899)
# split_loss=8.559820175-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(251/9899)
# split_loss=7.150449753-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(301/9899)
# split_loss=7.790458202-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(351/9899)
# split_loss=10.776861191-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(401/9899)
# split_loss=10.944593430-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(451/9899)
# split_loss=11.212833405-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(501/9899)
# split_loss=8.605630875-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(551/9899)
# split_loss=8.148725510-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(601/9899)
# split_loss=11.373610497-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(651/9899)
# split_loss=9.509510994-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(701/9899)
# split_loss=8.769033432-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(751/9899)
# split_loss=8.908009529-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(801/9899)
# split_loss=11.923770905-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(851/9899)
# split_loss=9.746409416-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(901/9899)
# split_loss=12.946644783-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(951/9899)
# split_loss=13.397769928-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1001/9899)
# split_loss=9.578042984-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1051/9899)
# split_loss=8.035804749-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1101/9899)
# split_loss=8.417594910-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1151/9899)
# split_loss=8.706890106-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1201/9899)
# split_loss=14.228147507-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1251/9899)
# split_loss=9.462107658-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1301/9899)
# split_loss=8.916872978-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1351/9899)
# split_loss=11.821603775-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1401/9899)
# split_loss=9.363346100-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1451/9899)
# split_loss=10.038495064-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1501/9899)
# split_loss=7.686465263-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1551/9899)
# split_loss=7.895262718-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1601/9899)
# split_loss=6.808632851-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1651/9899)
# split_loss=8.791266441-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1701/9899)
# split_loss=8.187235832-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1751/9899)
# split_loss=9.322202682-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1801/9899)
# split_loss=6.950055599-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1851/9899)
# split_loss=7.297410965-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1901/9899)
# split_loss=15.105051041-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(1951/9899)
# split_loss=9.974741936-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2001/9899)
# split_loss=7.401495934-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2051/9899)
# split_loss=6.986402035-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2101/9899)
# split_loss=8.072567940-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2151/9899)
# split_loss=7.694575310-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2201/9899)
# split_loss=10.409459114-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2251/9899)
# split_loss=10.630319595-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2301/9899)
# split_loss=7.901257038-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2351/9899)
# split_loss=9.749636650-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2401/9899)
# split_loss=8.528036118-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2451/9899)
# split_loss=8.352300644-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2501/9899)
# split_loss=8.043603897-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2551/9899)
# split_loss=7.846177578-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2601/9899)
# split_loss=12.294529915-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2651/9899)
# split_loss=15.375075340-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2701/9899)
# split_loss=10.939602852-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2751/9899)
# split_loss=13.174173355-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2801/9899)
# split_loss=11.433167458-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2851/9899)
# split_loss=10.213582993-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2901/9899)
# split_loss=7.525276184-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(2951/9899)
# split_loss=11.990242004-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3001/9899)
# split_loss=11.688121796-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3051/9899)
# split_loss=12.478568077-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3101/9899)
# split_loss=11.355550766-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3151/9899)
# split_loss=8.323585510-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3201/9899)
# split_loss=10.329852104-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3251/9899)
# split_loss=10.710740089-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3301/9899)
# split_loss=11.370405197-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3351/9899)
# split_loss=12.415915489-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3401/9899)
# split_loss=12.274503708-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3451/9899)
# split_loss=6.825674057-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3501/9899)
# split_loss=11.865610123-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3551/9899)
# split_loss=10.007899284-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3601/9899)
# split_loss=11.426280975-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3651/9899)
# split_loss=11.882350922-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3701/9899)
# split_loss=12.879386902-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3751/9899)
# split_loss=10.843944550-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3801/9899)
# split_loss=12.135372162-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3851/9899)
# split_loss=9.635028839-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3901/9899)
# split_loss=10.794412613-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(3951/9899)
# split_loss=10.497401237-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4001/9899)
# split_loss=10.191722870-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4051/9899)
# split_loss=10.556709290-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4101/9899)
# split_loss=10.642436981-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4151/9899)
# split_loss=10.890909195-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4201/9899)
# split_loss=9.106369019-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4251/9899)
# split_loss=7.941907883-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4301/9899)
# split_loss=10.780842781-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4351/9899)
# split_loss=14.215173721-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4401/9899)
# split_loss=15.388293266-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4451/9899)
# split_loss=12.798874855-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4501/9899)
# split_loss=11.730813980-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4551/9899)
# split_loss=12.314749718-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4601/9899)
# split_loss=11.322319031-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4651/9899)
# split_loss=9.214201927-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4701/9899)
# split_loss=8.697809219-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4751/9899)
# split_loss=9.340918541-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4801/9899)
# split_loss=6.979572296-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4851/9899)
# split_loss=7.793339729-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4901/9899)
# split_loss=5.592215061-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(4951/9899)
# split_loss=11.564096451-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5001/9899)
# split_loss=6.748158932-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5051/9899)
# split_loss=7.825248241-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5101/9899)
# split_loss=7.753225327-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5151/9899)
# split_loss=7.484559059-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5201/9899)
# split_loss=9.239358902-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5251/9899)
# split_loss=7.108982086-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5301/9899)
# split_loss=6.489251614-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5351/9899)
# split_loss=6.483110905-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5401/9899)
# split_loss=10.408077240-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5451/9899)
# split_loss=6.978375435-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5501/9899)
# split_loss=7.137675762-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5551/9899)
# split_loss=5.468739510-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5601/9899)
# split_loss=8.942964554-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5651/9899)
# split_loss=11.618065834-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5701/9899)
# split_loss=11.615489006-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5751/9899)
# split_loss=9.965236664-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5801/9899)
# split_loss=10.253852844-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5851/9899)
# split_loss=9.088612556-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5901/9899)
# split_loss=8.493495941-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(5951/9899)
# split_loss=6.948659897-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6001/9899)
# split_loss=8.725649834-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6051/9899)
# split_loss=7.910863876-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6101/9899)
# split_loss=6.797085762-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6151/9899)
# split_loss=6.544062614-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6201/9899)
# split_loss=6.470013142-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6251/9899)
# split_loss=7.265375614-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6301/9899)
# split_loss=5.871658802-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6351/9899)
# split_loss=7.906122684-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6401/9899)
# split_loss=7.421535015-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6451/9899)
# split_loss=7.842184544-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6501/9899)
# split_loss=11.311915398-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6551/9899)
# split_loss=12.318349838-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6601/9899)
# split_loss=11.417613983-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6651/9899)
# split_loss=8.605728149-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6701/9899)
# split_loss=11.930341721-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6751/9899)
# split_loss=8.226051331-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6801/9899)
# split_loss=7.324567318-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6851/9899)
# split_loss=6.657505035-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6901/9899)
# split_loss=6.954859734-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(6951/9899)
# split_loss=7.383792400-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7001/9899)
# split_loss=8.401705742-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7051/9899)
# split_loss=9.342601776-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7101/9899)
# split_loss=10.179585457-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7151/9899)
# split_loss=9.556997299-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7201/9899)
# split_loss=9.711140633-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7251/9899)
# split_loss=6.288652897-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7301/9899)
# split_loss=10.277605057-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7351/9899)
# split_loss=5.669639111-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7401/9899)
# split_loss=5.902067661-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7451/9899)
# split_loss=9.562059402-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7501/9899)
# split_loss=8.842829704-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7551/9899)
# split_loss=4.870691776-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7601/9899)
# split_loss=9.099543571-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7651/9899)
# split_loss=10.168393135-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7701/9899)
# split_loss=8.251404762-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7751/9899)
# split_loss=10.699069023-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7801/9899)
# split_loss=8.574785233-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7851/9899)
# split_loss=10.469512939-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7901/9899)
# split_loss=6.153168201-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(7951/9899)
# split_loss=5.178718567-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8001/9899)
# split_loss=10.202855110-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8051/9899)
# split_loss=10.286461830-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8101/9899)
# split_loss=8.592479706-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8151/9899)
# split_loss=8.310510635-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8201/9899)
# split_loss=8.313775063-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8251/9899)
# split_loss=8.405656815-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8301/9899)
# split_loss=6.704420090-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8351/9899)
# split_loss=5.201544762-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8401/9899)
# split_loss=8.230855942-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8451/9899)
# split_loss=8.772385597-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8501/9899)
# split_loss=8.575516701-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8551/9899)
# split_loss=9.706470490-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8601/9899)
# split_loss=5.463945389-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8651/9899)
# split_loss=9.932959557-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8701/9899)
# split_loss=8.370219231-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8751/9899)
# split_loss=5.524854660-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8801/9899)
# split_loss=5.459355354-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8851/9899)
# split_loss=8.430051804-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8901/9899)
# split_loss=12.292203903-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(8951/9899)
# split_loss=10.130897522-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9001/9899)
# split_loss=13.146207809-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9051/9899)
# split_loss=10.695075035-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9101/9899)
# split_loss=13.334793091-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9151/9899)
# split_loss=11.761882782-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9201/9899)
# split_loss=12.663901329-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9251/9899)
# split_loss=8.304300308-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9301/9899)
# split_loss=9.207364082-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9351/9899)
# split_loss=5.854191780-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9401/9899)
# split_loss=6.894320011-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9451/9899)
# split_loss=8.745101929-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9501/9899)
# split_loss=5.252418995-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9551/9899)
# split_loss=5.016897678-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9601/9899)
# split_loss=7.912732124-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9651/9899)
# split_loss=8.029034615-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9701/9899)
# split_loss=7.638245583-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9751/9899)
# split_loss=7.235174656-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9801/9899)
# split_loss=6.250283241-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=0-batch_id=(9851/9899)
# split_loss=6.505425453-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1/9899)
# split_loss=5.480910301-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(51/9899)
# split_loss=6.203521252-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(101/9899)
# split_loss=5.829864502-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(151/9899)
# split_loss=6.584093094-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(201/9899)
# split_loss=5.375010967-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(251/9899)
# split_loss=5.370181561-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(301/9899)
# split_loss=5.621052265-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(351/9899)
# split_loss=7.085719585-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(401/9899)
# split_loss=7.299313545-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(451/9899)
# split_loss=7.877189159-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(501/9899)
# split_loss=5.392758369-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(551/9899)
# split_loss=6.018702984-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(601/9899)
# split_loss=7.878448486-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(651/9899)
# split_loss=6.833523750-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(701/9899)
# split_loss=6.020581722-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(751/9899)
# split_loss=4.740432262-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(801/9899)
# split_loss=6.528271675-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(851/9899)
# split_loss=6.579826355-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(901/9899)
# split_loss=5.914308548-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(951/9899)
# split_loss=6.702229977-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1001/9899)
# split_loss=5.672204494-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1051/9899)
# split_loss=4.397927761-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1101/9899)
# split_loss=5.611920357-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1151/9899)
# split_loss=5.334314823-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1201/9899)
# split_loss=5.652497292-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1251/9899)
# split_loss=5.394585609-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1301/9899)
# split_loss=5.512831211-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1351/9899)
# split_loss=5.476260185-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1401/9899)
# split_loss=5.139962196-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1451/9899)
# split_loss=4.390806675-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1501/9899)
# split_loss=4.382657051-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1551/9899)
# split_loss=5.112782955-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1601/9899)
# split_loss=5.075010300-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1651/9899)
# split_loss=4.904145718-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1701/9899)
# split_loss=3.862281561-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1751/9899)
# split_loss=5.374353409-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1801/9899)
# split_loss=5.372031689-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1851/9899)
# split_loss=5.143445969-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1901/9899)
# split_loss=5.489001274-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(1951/9899)
# split_loss=5.133253098-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2001/9899)
# split_loss=4.642148495-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2051/9899)
# split_loss=4.783602238-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2101/9899)
# split_loss=4.339085102-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2151/9899)
# split_loss=4.778099060-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2201/9899)
# split_loss=4.591583252-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2251/9899)
# split_loss=5.027763367-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2301/9899)
# split_loss=4.481465340-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2351/9899)
# split_loss=4.706463814-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2401/9899)
# split_loss=4.712720871-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2451/9899)
# split_loss=5.007163525-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2501/9899)
# split_loss=5.221051693-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2551/9899)
# split_loss=5.120886326-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2601/9899)
# split_loss=4.606256962-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2651/9899)
# split_loss=4.973144054-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2701/9899)
# split_loss=4.880846024-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2751/9899)
# split_loss=5.381663799-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2801/9899)
# split_loss=5.383486748-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2851/9899)
# split_loss=4.649079323-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2901/9899)
# split_loss=4.995963573-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(2951/9899)
# split_loss=5.327095509-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3001/9899)
# split_loss=5.294918060-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3051/9899)
# split_loss=4.797774792-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3101/9899)
# split_loss=5.260129452-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3151/9899)
# split_loss=4.966867924-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3201/9899)
# split_loss=4.658729076-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3251/9899)
# split_loss=4.775960445-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3301/9899)
# split_loss=5.446239471-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3351/9899)
# split_loss=4.855969906-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3401/9899)
# split_loss=5.205611229-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3451/9899)
# split_loss=4.794538498-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3501/9899)
# split_loss=5.252006054-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3551/9899)
# split_loss=4.635982037-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3601/9899)
# split_loss=4.035692692-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3651/9899)
# split_loss=5.305900574-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3701/9899)
# split_loss=4.952538490-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3751/9899)
# split_loss=4.687020779-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3801/9899)
# split_loss=5.592056274-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3851/9899)
# split_loss=5.078007698-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3901/9899)
# split_loss=4.062553883-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(3951/9899)
# split_loss=5.100365162-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4001/9899)
# split_loss=4.813989639-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4051/9899)
# split_loss=5.397216797-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4101/9899)
# split_loss=5.265782356-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4151/9899)
# split_loss=4.856475353-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4201/9899)
# split_loss=4.262456894-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4251/9899)
# split_loss=4.577192783-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4301/9899)
# split_loss=5.240012169-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4351/9899)
# split_loss=4.480214119-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4401/9899)
# split_loss=5.133471012-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4451/9899)
# split_loss=4.903686523-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4501/9899)
# split_loss=4.518248081-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4551/9899)
# split_loss=4.748788357-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4601/9899)
# split_loss=4.854899883-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4651/9899)
# split_loss=5.239151001-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4701/9899)
# split_loss=4.363721848-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4751/9899)
# split_loss=5.052042484-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4801/9899)
# split_loss=4.660472870-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4851/9899)
# split_loss=4.929214954-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4901/9899)
# split_loss=4.325866699-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(4951/9899)
# split_loss=4.582843304-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5001/9899)
# split_loss=5.107577324-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5051/9899)
# split_loss=4.100493431-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5101/9899)
# split_loss=5.000078201-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5151/9899)
# split_loss=4.557122707-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5201/9899)
# split_loss=4.508177757-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5251/9899)
# split_loss=4.687874317-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5301/9899)
# split_loss=3.598102808-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5351/9899)
# split_loss=3.946969986-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5401/9899)
# split_loss=3.922244787-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5451/9899)
# split_loss=4.873012543-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5501/9899)
# split_loss=4.058586597-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5551/9899)
# split_loss=4.315566540-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5601/9899)
# split_loss=4.707542896-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5651/9899)
# split_loss=4.733511448-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5701/9899)
# split_loss=4.793683052-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5751/9899)
# split_loss=3.817428112-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5801/9899)
# split_loss=4.480096817-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5851/9899)
# split_loss=4.481125832-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5901/9899)
# split_loss=4.745571613-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(5951/9899)
# split_loss=4.500798702-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6001/9899)
# split_loss=4.250518322-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6051/9899)
# split_loss=4.989661217-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6101/9899)
# split_loss=4.597954750-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6151/9899)
# split_loss=4.429544449-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6201/9899)
# split_loss=4.956624508-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6251/9899)
# split_loss=4.985404491-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6301/9899)
# split_loss=4.960962772-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6351/9899)
# split_loss=4.861929417-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6401/9899)
# split_loss=4.753891945-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6451/9899)
# split_loss=4.310139179-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6501/9899)
# split_loss=4.946915627-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6551/9899)
# split_loss=4.455848694-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6601/9899)
# split_loss=5.229370117-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6651/9899)
# split_loss=4.988060951-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6701/9899)
# split_loss=4.132331848-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6751/9899)
# split_loss=4.819005489-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6801/9899)
# split_loss=3.494150162-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6851/9899)
# split_loss=3.896945715-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6901/9899)
# split_loss=4.342987061-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(6951/9899)
# split_loss=4.194582462-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7001/9899)
# split_loss=4.230058193-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7051/9899)
# split_loss=4.704317570-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7101/9899)
# split_loss=4.936187744-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7151/9899)
# split_loss=4.068138123-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7201/9899)
# split_loss=4.188870907-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7251/9899)
# split_loss=5.211168289-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7301/9899)
# split_loss=4.779083729-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7351/9899)
# split_loss=4.365962505-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7401/9899)
# split_loss=4.756448269-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7451/9899)
# split_loss=4.367135048-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7501/9899)
# split_loss=4.366959095-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7551/9899)
# split_loss=4.504067421-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7601/9899)
# split_loss=5.134010315-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7651/9899)
# split_loss=4.413190842-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7701/9899)
# split_loss=4.849963188-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7751/9899)
# split_loss=4.815375328-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7801/9899)
# split_loss=4.528314590-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7851/9899)
# split_loss=4.358691216-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7901/9899)
# split_loss=4.815366268-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(7951/9899)
# split_loss=4.141546726-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8001/9899)
# split_loss=4.810885906-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8051/9899)
# split_loss=4.961669445-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8101/9899)
# split_loss=4.584712982-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8151/9899)
# split_loss=4.734984875-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8201/9899)
# split_loss=4.638486862-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8251/9899)
# split_loss=4.207531452-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8301/9899)
# split_loss=4.783909798-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8351/9899)
# split_loss=4.659490585-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8401/9899)
# split_loss=3.657638073-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8451/9899)
# split_loss=3.901586294-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8501/9899)
# split_loss=4.805345058-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8551/9899)
# split_loss=4.509669304-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8601/9899)
# split_loss=4.765777588-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8651/9899)
# split_loss=4.180492878-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8701/9899)
# split_loss=4.481991291-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8751/9899)
# split_loss=4.862334251-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8801/9899)
# split_loss=4.860302448-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8851/9899)
# split_loss=4.448640347-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8901/9899)
# split_loss=5.019735813-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(8951/9899)
# split_loss=4.778844357-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9001/9899)
# split_loss=4.171602726-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9051/9899)
# split_loss=4.292633057-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9101/9899)
# split_loss=4.618874073-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9151/9899)
# split_loss=4.208359718-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9201/9899)
# split_loss=4.790854454-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9251/9899)
# split_loss=4.696959972-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9301/9899)
# split_loss=4.484324932-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=1-batch_id=(9351/9899)
# ...
# split_loss=4.191445827-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8001/9899)
# split_loss=4.793902397-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8051/9899)
# split_loss=4.443890095-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8101/9899)
# split_loss=4.977434158-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8151/9899)
# split_loss=4.449840546-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8201/9899)
# split_loss=4.651937485-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8251/9899)
# split_loss=4.097467899-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8301/9899)
# split_loss=4.178203106-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8351/9899)
# split_loss=4.030461311-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8401/9899)
# split_loss=4.735695362-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8451/9899)
# split_loss=4.770883083-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8501/9899)
# split_loss=4.765808105-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8551/9899)
# split_loss=4.557139874-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8601/9899)
# split_loss=4.823928356-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8651/9899)
# split_loss=5.153314590-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8701/9899)
# split_loss=4.995422840-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8751/9899)
# split_loss=3.917535067-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8801/9899)
# split_loss=3.834420443-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8851/9899)
# split_loss=3.608626127-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8901/9899)
# split_loss=3.673282623-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(8951/9899)
# split_loss=4.299357414-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9001/9899)
# split_loss=4.167507172-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9051/9899)
# split_loss=4.285372734-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9101/9899)
# split_loss=3.787196159-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9151/9899)
# split_loss=4.463794708-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9201/9899)
# split_loss=3.896914005-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9251/9899)
# split_loss=4.047490120-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9301/9899)
# split_loss=3.547169685-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9351/9899)
# split_loss=4.021254063-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9401/9899)
# split_loss=3.265289307-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9451/9899)
# split_loss=3.434882402-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9501/9899)
# split_loss=3.900330067-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9551/9899)
# split_loss=4.378430367-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9601/9899)
# split_loss=4.259100914-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9651/9899)
# split_loss=4.471228123-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9701/9899)
# split_loss=4.447885036-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9751/9899)
# split_loss=3.997195721-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9801/9899)
# split_loss=3.602882624-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=6-batch_id=(9851/9899)
# split_loss=4.279534817-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1/9899)
# split_loss=4.262948513-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(51/9899)
# split_loss=4.419816017-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(101/9899)
# split_loss=4.253885746-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(151/9899)
# split_loss=4.513601780-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(201/9899)
# split_loss=4.451482296-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(251/9899)
# split_loss=4.176881790-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(301/9899)
# split_loss=3.561390400-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(351/9899)
# split_loss=3.928601742-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(401/9899)
# split_loss=4.829477310-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(451/9899)
# split_loss=4.508375168-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(501/9899)
# split_loss=4.161889553-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(551/9899)
# split_loss=4.612470627-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(601/9899)
# split_loss=4.485648632-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(651/9899)
# split_loss=3.957885742-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(701/9899)
# split_loss=3.550157547-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(751/9899)
# split_loss=4.610903740-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(801/9899)
# split_loss=3.379411936-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(851/9899)
# split_loss=3.716784477-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(901/9899)
# split_loss=4.181391716-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(951/9899)
# split_loss=4.382844448-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1001/9899)
# split_loss=3.904360056-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1051/9899)
# split_loss=4.079800606-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1101/9899)
# split_loss=3.614340782-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1151/9899)
# split_loss=4.193297863-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1201/9899)
# split_loss=4.110000134-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1251/9899)
# split_loss=3.945719719-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1301/9899)
# split_loss=4.013223648-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1351/9899)
# split_loss=4.504456520-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1401/9899)
# split_loss=4.323356152-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1451/9899)
# split_loss=3.942121506-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1501/9899)
# split_loss=4.180258274-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1551/9899)
# split_loss=4.037581921-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1601/9899)
# split_loss=4.106410980-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1651/9899)
# split_loss=4.054417610-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1701/9899)
# split_loss=4.330821991-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1751/9899)
# split_loss=4.406387329-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1801/9899)
# split_loss=3.917985439-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1851/9899)
# split_loss=4.321543217-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1901/9899)
# split_loss=4.351009369-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(1951/9899)
# split_loss=4.214545250-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2001/9899)
# split_loss=4.425687313-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2051/9899)
# split_loss=3.548532486-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2101/9899)
# split_loss=4.092846394-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2151/9899)
# split_loss=3.629981995-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2201/9899)
# split_loss=4.516481876-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2251/9899)
# split_loss=2.799649715-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2301/9899)
# split_loss=4.684973240-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2351/9899)
# split_loss=4.292972088-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2401/9899)
# split_loss=4.082293034-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2451/9899)
# split_loss=4.197593689-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2501/9899)
# split_loss=4.774438381-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2551/9899)
# split_loss=3.931702614-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2601/9899)
# split_loss=4.671966076-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2651/9899)
# split_loss=3.795119524-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2701/9899)
# split_loss=4.078608513-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2751/9899)
# split_loss=3.846760511-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2801/9899)
# split_loss=4.523344040-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2851/9899)
# split_loss=4.231222153-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2901/9899)
# split_loss=4.732346058-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(2951/9899)
# split_loss=4.499819279-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3001/9899)
# split_loss=4.218500137-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3051/9899)
# split_loss=4.342907429-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3101/9899)
# split_loss=4.572748184-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3151/9899)
# split_loss=4.046254635-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3201/9899)
# split_loss=4.129381657-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3251/9899)
# split_loss=4.141443253-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3301/9899)
# split_loss=4.101326466-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3351/9899)
# split_loss=4.342425346-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3401/9899)
# split_loss=4.212686062-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3451/9899)
# split_loss=4.470495701-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3501/9899)
# split_loss=5.012948513-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3551/9899)
# split_loss=5.277842522-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3601/9899)
# split_loss=4.016739368-train_bleu_mean=-1.000000000-train_bleu_max=-1.000000000-batch_size=100-epoch=7-batch_id=(3651/9899)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-5ccc27329b2a> in <module>()
#     114
#     115 for epoch in range(epochs):
# --> 116     model_train(epoch, batch_size, split_train_set_size)
#     117
#     118 print('running time: %.2f mins'%((time.time()-start_time)/60))
#
# <ipython-input-8-5ccc27329b2a> in model_train(epoch, batch_size, train_set_size)
#      35                                      torch.LongTensor(split_train_set_input_lens[start_idx:end_idx]),
#      36                                                 )
# ---> 37         loss = language_model.get_loss(outputs, torch.LongTensor(split_train_set_labels[start_idx:end_idx]))
#      38
#      39         #optimize
#
# <ipython-input-5-899bea8f66d4> in get_loss(self, logits, labels)
#      79
#      80     def get_loss(self, logits, labels):
# ---> 81         labels = self._tocuda(Variable(labels))
#      82         sents = logits.size(dim=1)
#      83         labels = labels[:, :sents]
#
# <ipython-input-5-899bea8f66d4> in _tocuda(self, var)
#      93     def _tocuda(self, var):
#      94         if self.use_cuda:
# ---> 95             return var.cuda()
#      96         else:
#      97             return var
#
# /data1/hmx/anaconda3/lib/python3.5/site-packages/torch/autograd/variable.py in cuda(self, device, async)
#     296
#     297     def cuda(self, device=None, async=False):
# --> 298         return CudaTransfer.apply(self, device, async)
#     299
#     300     def cpu(self):
#
# /data1/hmx/anaconda3/lib/python3.5/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, device, async)
#     199             return i.cuda(device, async=async)
#     200         else:
# --> 201             return i.cuda(async=async)
#     202
#     203     @staticmethod
#
# /data1/hmx/anaconda3/lib/python3.5/site-packages/torch/_utils.py in _cuda(self, device, async)
#      67         else:
#      68             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 69             return new_type(self.size()).copy_(self, async)
#      70
#      71
#
# KeyboardInterrupt:

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-30d9529ff51c> in <module>()
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
use_cuda = 1
hidden_dim = 512
input_dim = 300
lr=0.005
batch_size=100
split_train_set_size=int(len(split_train_set_inputs)/1)
epochs=10000
train_bleu_mean=-1
train_bleu_max=-1

language_model = LanguageModel(use_cuda = use_cuda, input_dim = input_dim, hidden_dim = hidden_dim, vocab = vocab)
model_path = './models_language_model/time-[2019-02-26-01-34-36]-info=[language_model]-loss=4.287574768-bleu=-1.0000-hidden_dim=512-input_dim=300-epoch=5-batch_size=100-batch_id=[1-[of]-9899]-lr=0.0050'
model_path = './models_language_model/time-[2019-02-26-05-54-37]-info=[language_model]-loss=4.003368378-bleu=-1.0000-hidden_dim=512-input_dim=300-epoch=12-batch_size=100-batch_id=[1-[of]-9899]-lr=0.0050'
model_path = './models_language_model/time-[2019-02-26-11-27-36]-info=[language_model]-loss=3.414012194-bleu=-1.0000-hidden_dim=512-input_dim=300-epoch=21-batch_size=100-batch_id=[1-[of]-9899]-lr=0.0050'
pre_train = torch.load(model_path, map_location='cpu')
language_model.load_state_dict(pre_train)

if use_cuda:
    language_model = language_model.cuda()

# %%
data_range = int((len(split_valid_set_inputs)-1)/100)
rand_idx=random.randint(0, data_range)
sample_num=2
language_model.eval()
logits = language_model.forward(torch.LongTensor(split_valid_set_inputs[rand_idx:rand_idx+sample_num]), 
                                     torch.LongTensor(split_valid_set_input_lens[rand_idx:rand_idx+sample_num]),
                                                )
print(logits.size())
_, predicts = logits.max(dim=2)
predicts = predicts.cpu().data.tolist()
predicts = batch_tokens_remove_eos(tokens_list=predicts, vocab=vocab)
words_list = batch_tokens2words(predicts, vocab)
sents = batch_words2sentence(words_list=words_list)
for sent in sents:
    print(sent)

print('\n')

#labels
labels=split_valid_set_labels[rand_idx:rand_idx+sample_num]
labels = batch_tokens_remove_eos(tokens_list=labels, vocab=vocab)
words_list = batch_tokens2words(labels, vocab)
sents = batch_words2sentence(words_list=words_list)
for sent in sents:
    print(sent)
    
language_model.train()
print('\n')

# %%
k

# %%
#300d
split_model_path='./models_saved/time-[2019-02-24-14-50-48]-info=[split_model]-loss=1.512540460-bleu=0.0136-hidden_dim=512-input_dim=300-epoch=48-batch_size=200-batch_id=[1-[of]-494]-lr=0.0050'
fusion_model_path='./models_saved/time-[2019-02-24-14-50-49]-info=[fusion_model]-loss=1.444324136-bleu=0.0243-hidden_dim=512-input_dim=300-epoch=48-batch_size=200-batch_id=[1-[of]-494]-lr=0.0050'

#300d
split_model_path='./models_saved/time-[2019-02-24-06-03-39]-info=[split_model]-loss=1.667227983-bleu=0.0144-hidden_dim=512-input_dim=300-epoch=22-batch_size=200-batch_id=[1-[of]-494]-lr=0.0050'
fusion_model_path='./models_saved/time-[2019-02-24-06-03-39]-info=[fusion_model]-loss=1.542479157-bleu=0.0147-hidden_dim=512-input_dim=300-epoch=22-batch_size=200-batch_id=[1-[of]-494]-lr=0.0050'

#100d
# split_model_path='./models_saved/time-[2019-01-24-17-17-59]-info=[split_model]-loss=1.704468250-bleu=0.0485-hidden_dim=256-input_dim=100-epoch=9-batch_size=200-batch_id=[1-[of]-4949]-lr=0.0050'
# fusion_model_path='./models_saved/time-[2019-01-24-17-17-59]-info=[fusion_model]-loss=2.401571035-bleu=0.0334-hidden_dim=256-input_dim=100-epoch=9-batch_size=200-batch_id=[1-[of]-4949]-lr=0.0050'

use_cuda = 1
hidden_dim = 512
input_dim = 300
lr=0.005
batch_size=200
split_train_set_size=int(len(split_train_set_inputs)/10)
epochs=10000
train_bleu_mean=-1
train_bleu_max=-1
split_model = Seq2Seq(use_cuda = use_cuda, input_dim = input_dim, hidden_dim = hidden_dim, 
                          vocab = vocab, max_length = 61)

fusion_model = Seq2Seq(use_cuda = use_cuda, input_dim = input_dim, hidden_dim = hidden_dim, 
                          vocab = vocab, max_length = 51)
#pre train para
pre_train = torch.load(split_model_path, map_location='cpu')
split_model.load_state_dict(pre_train)
pre_train = torch.load(fusion_model_path, map_location='cpu')
fusion_model.load_state_dict(pre_train)

if use_cuda:
    split_model = split_model.cuda()
    fusion_model = fusion_model.cuda()

# %%
rand_idx=80300
sample_num=100

loss_, predicts = fusion_model.forward(torch.LongTensor(fusion_pseudo_train_set_inputs[rand_idx:rand_idx+sample_num]), 
                                             torch.LongTensor(fusion_pseudo_train_set_input_lens[rand_idx:rand_idx+sample_num]), 
                                             labels=torch.LongTensor(fusion_pseudo_train_set_labels[rand_idx:rand_idx+sample_num]), 
                                             is_train=1, teaching_rate=1)
# del loss_

predicts = batch_tokens_remove_eos(predicts, vocab)
labels = batch_tokens_remove_eos(fusion_pseudo_train_set_labels[rand_idx:rand_idx+sample_num], vocab)

bleu_scores = batch_tokens_bleu(references=labels, candidates=predicts, smooth_epsilon=0.001)

train_bleu = 0
for x in bleu_scores:
    train_bleu+=x
train_bleu/=len(bleu_scores)
print(train_bleu)
                
# predicts = batch_tokens2words(predicts, vocab)
# labels = batch_tokens2words(labels, vocab)

# predicts_sents = batch_words2sentence(predicts)
# labels_sents = batch_words2sentence(labels)

# for (predict_sent, label_sent) in zip(predicts_sents, labels_sents):
#     print(' 1----> ', predict_sent)
#     print(' 2----> ', label_sent)
#     print('\n')

predicts = fusion_model.forward(torch.LongTensor(fusion_pseudo_train_set_inputs[rand_idx:rand_idx+sample_num]), 
                                             torch.LongTensor(fusion_pseudo_train_set_input_lens[rand_idx:rand_idx+sample_num]), 
                                             labels=torch.LongTensor(fusion_pseudo_train_set_labels[rand_idx:rand_idx+sample_num]), 
                                             is_train=0, teaching_rate=1)
# del loss_

predicts = batch_tokens_remove_eos(predicts, vocab)
labels = batch_tokens_remove_eos(fusion_pseudo_train_set_labels[rand_idx:rand_idx+sample_num], vocab)

bleu_scores = batch_tokens_bleu(references=labels, candidates=predicts, smooth_epsilon=0.001)

train_bleu = 0
for x in bleu_scores:
    train_bleu+=x
train_bleu/=len(bleu_scores)
print(train_bleu)


rand_idx=3000
batch_size=100
loss_, predicts = fusion_model.forward(torch.LongTensor(fusion_pseudo_valid_set_inputs[rand_idx:rand_idx+batch_size]), 
                                                 torch.LongTensor(fusion_pseudo_valid_set_input_lens[rand_idx:rand_idx+batch_size]), 
                                                 labels=torch.LongTensor(fusion_pseudo_valid_set_labels[rand_idx:rand_idx+batch_size]),
                                                 is_train=1, teaching_rate=1)
predicts = batch_tokens_remove_eos(predicts, vocab)
labels = batch_tokens_remove_eos(fusion_pseudo_valid_set_labels[rand_idx:rand_idx+batch_size], vocab)

bleu_scores = batch_tokens_bleu(references=labels, candidates=predicts, smooth_epsilon=0.001)

valid_bleu = 0
for x in bleu_scores:
    valid_bleu+=x
valid_bleu/=len(bleu_scores)
print(valid_bleu)


predicts = fusion_model.forward(torch.LongTensor(fusion_pseudo_valid_set_inputs[rand_idx:rand_idx+batch_size]), 
                                                 torch.LongTensor(fusion_pseudo_valid_set_input_lens[rand_idx:rand_idx+batch_size]), 
                                                 labels=torch.LongTensor(fusion_pseudo_valid_set_labels[rand_idx:rand_idx+batch_size]),
                                                 is_train=0, teaching_rate=1)
predicts = batch_tokens_remove_eos(predicts, vocab)
labels = batch_tokens_remove_eos(fusion_pseudo_valid_set_labels[rand_idx:rand_idx+batch_size], vocab)

bleu_scores = batch_tokens_bleu(references=labels, candidates=predicts, smooth_epsilon=0.001)

valid_bleu = 0
for x in bleu_scores:
    valid_bleu+=x
valid_bleu/=len(bleu_scores)
print(valid_bleu)
